# %%
from pyspark import *

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("q1").getOrCreate()

# %%
from pyspark.sql.functions import *

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#                                               0.0/250.9 kB ? eta -:--:--
#      -----------                             71.7/250.9 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------  245.8/250.9 kB 3.0 MB/s eta 0:00:01
#      -------------------------------------- 250.9/250.9 kB 2.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (d:\anaconda\envs\gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (d:\anaconda\envs\gpu\lib\site-packages)

# %%
#step 1
# 1. Data Loading

file_path = "abc.csv"

df = pd.read_csv(file_path)
# df = .read.csv(
#     file_path,
#     header=True,       # Treat the first row as the header
#     inferSchema=True,  # Infer data types automatically
#     quote='"',         # Handle quoted strings properly
#     escape='"',        # Escape embedded quotes within strings
# #     multiLine=True     # Handle multiline records
# )

# Display the DataFrame
df = spark.createDataFrame(df)
df.show(truncate=False)
df.printSchema()

# data_pd = pd.read_excel(file_path)
# df = spark.createDataFrame(data_pd)
# df.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[24], line 6
#       1 #step 1
#       2 # 1. Data Loading
#       4 file_path = "abc.csv"
# ----> 6 df = pd.read_csv(file_path)
#       7 # df = .read.csv(
#       8 #     file_path,
#       9 #     header=True,       # Treat the first row as the header
#    (...)
#      15
#      16 # Display the DataFrame
#      17 df = spark.createDataFrame(df)
#
# File D:\Anaconda\envs\gpu\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\Anaconda\envs\gpu\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
# ...

# %%
null_counts = data.select([count(when(col(c).isNull() | isnan(c), c)).alias(c) for c in data.columns])
null_counts.show()

# Identify columns with unexpected data types or malformed values
for column in data.columns:
    data.select(column).distinct().show(truncate=False)
# Out:
# +------+----+-----+------+-----+-------+-----+
# |MOVIES|YEAR|GENRE|RATING|VOTES|RunTime|Gross|
# +------+----+-----+------+-----+-------+-----+
# |     0|  18|   19|  1688| 1836|   2136| 2996|
# +------+----+-----+------+-----+-------+-----+
#
# +-----------------------------------------------+
# |MOVIES                                         |
# +-----------------------------------------------+
# |Biohackers                                     |
# |The Ritual                                     |
# |Okja                                           |
# |The Laundromat                                 |
# |I Don't Feel at Home in This World Anymore     |
# |The K2                                         |
# |El baile de los 41                             |
# |Bom Dia, Ver̫nica                             |
# |13 Reasons Why                                 |
# |Narcos: M̩xico                                |
# |Birdman or (The Unexpected Virtue of Ignorance)|
# ...
